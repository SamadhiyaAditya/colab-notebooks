# %%
# 1️⃣ Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2️⃣ Set git user info
# !git config --global user.name "Aditya Samadhiya"
# !git config --global user.email "adityasamadhiya003@gmail.com"

# 3️⃣ Get GitHub PAT from Colab Secrets
from google.colab import userdata
key = userdata.get('key')  # replace 'key' with your secret name if different

# 4️⃣ Clone repo if it doesn't exist, else just pull latest changes
import os
repo_path = "/content/colab-notebooks"

if not os.path.exists(repo_path):
    # !git clone https://SamadhiyaAditya:{key}@github.com/SamadhiyaAditya/colab-notebooks.git
else:
    # %cd {repo_path}
    # !git pull https://SamadhiyaAditya:{key}@github.com/SamadhiyaAditya/colab-notebooks.git --rebase

# 5️⃣ Copy all notebooks from Drive to the repo folder
# !cp -r "/content/drive/MyDrive/Colab Notebooks/." "{repo_path}/"

# 6️⃣ Commit changes
# %cd {repo_path}
# !git add .
# !git commit -m "Update all notebooks from Colab" || echo "No changes to commit"

# 7️⃣ Push changes
# !git push https://SamadhiyaAditya:{key}@github.com/SamadhiyaAditya/colab-notebooks.git
