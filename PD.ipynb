# %%
import random as rd
seq=[3,5,7,3,1,2]
rd.shuffle(seq)
print(seq)
# Out:
# [1, 3, 7, 2, 5, 3]

# %%
rd.seed(5)
rd.randint(1,7)
# Out:
# 5

# %%
seq=['H','T']
w=rd.choices(seq,k=10)
print(w)
# Out:
# ['H', 'T', 'H', 'T', 'T', 'H', 'T', 'H', 'T', 'H']

# %%
seq=[0,0,0,1,1]
w=sum(rd.choices(seq,k=4))
print(w)
# Out:
# 3

# %%
r=rd.sample(seq,3)
print(r)
# Out:
# [0, 0, 1]
