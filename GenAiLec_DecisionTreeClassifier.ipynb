# %% [markdown]
# <a href="https://colab.research.google.com/github/SamadhiyaAditya/colab-notebooks/blob/main/GenAiLec_DecisionTreeClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('SUV_data.csv')
df
# Out:
#      Age  Salary  Purchased
# 0     56   45342          1
# 1     46   57157          1
# 2     32   87863          1
# 3     25   72083          0
# 4     38   85733          1
# ..   ...     ...        ...
# 195   23   40056          0
# 196   49   65543          1
# 197   21   76556          1
# 198   28   23343          0
# 199   34   33500          0
#
# [200 rows x 3 columns]

# %%
x=df[['Age','Salary']]
y=df['Purchased']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=DecisionTreeClassifier(max_depth=2)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
accuracy_score(y_test,model.predict(x_test))
# Out:
# 0.8

# %%
plt.figure(figsize=(12,8))
plot_tree(model,
          feature_names=['Age','Salary'],
          class_names=['Not Purchased','Purchased'],
          filled=True)
plt.show()

# %%
accuracy_score(y_test,model.predict(x_test))
# Out:
# 0.8

# %%
model=DecisionTreeClassifier(max_depth=2,min_samples_split=2,min_samples_leaf=1)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
accuracy_score(y_test,model.predict(x_test))
# Out:
# 0.8

# %%
param_grid={
    'max_depth':[2,3,4,5],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,5]
}
grid=GridSearchCV(DecisionTreeClassifier(),param_grid,cv=5)
grid.fit(x_train,y_train )
print("Best Params:", grid.best_params_)
# Out:
# Best Params: {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}
