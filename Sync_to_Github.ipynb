# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# cd /content
# if [ ! -d "colab-notebooks/.git" ]; then
#   git clone https://github.com/SamadhiyaAditya/colab-notebooks.git
# fi
# Out:
# Cloning into 'colab-notebooks'...
# ...

# %%
# %%bash
# # 3️⃣ Copy all notebooks from Drive to repo
# rsync -av --exclude='.git' "/content/drive/MyDrive/Colab Notebooks/" "/content/colab-notebooks/"
# Out:
# sending incremental file list
# ./
# 14 1 26_GenAiLab.ipynb
# 7 1 26-GenAiLab2.ipynb
# Copy of Activity.ipynb
# GenAiLab.ipynb
# GenAiLec-LogisticRegression.ipynb
# GenAiLecLinearProgression.ipynb
# Lec1.ipynb
# Lec2.ipynb
# PD.ipynb
# Sync_to_Github.ipynb
# scipy.ipynb
#
# sent 939,207 bytes  received 228 bytes  1,878,870.00 bytes/sec
# total size is 938,194  speedup is 1.00

# %%
# %%bash
# # 4️⃣ Commit & push changes
# cd /content/colab-notebooks
# git config user.name "Aditya Samadhiya"
# git config user.email "adityasamadhiya003@gmail.com"
# git add .
# git commit -m "Sync new notebooks from Drive" || echo "Nothing to commit"
# git push -u origin main
