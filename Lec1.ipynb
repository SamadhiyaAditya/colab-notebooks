# %%
# !gdown "https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX" -O dummy.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX
# To: /content/dummy.csv
# 100% 1.50k/1.50k [00:00<00:00, 4.28MB/s]

# %%
f= open("dummy.csv","r")
f.readline().split(',')
# Out:
# ['name',
#  'city',
#  'rating',
#  'cost_for_two',
#  'cusine',
#  'online_order',
#  'table_reservation\n']

# %%
import pandas as pd
df=pd.read_csv("https://drive.google.com/uc?export=download&id=1in_bJYfJ5Ahy8y9RcBhdqp0aKHguU7EX")

# %%
df
# Out:
#                                    name       city  rating  cost_for_two  \
# 0                Gabbar's Bar & Kitchen    Kolkata     4.3          1500
# 1           Sardaar Ji De Chole Bhature  Delhi NCR     3.6           100
# 2                           YellowKrust  Delhi NCR     3.8           400
# 3                       Hungry Minister  Delhi NCR     3.7           400
# 4                       Night Food Xprs  Delhi NCR     3.3           500
# 5                 HOP House of Proteins  Delhi NCR     4.8           600
# 6         Daana Paani Family Restaurant    Kolkata     3.4           300
# 7                       Swad Restaurant  Delhi NCR     3.8           750
# 8                        Chai Peeni Hai  Delhi NCR     3.7           200
# 9                        Baskin Robbins     Mumbai     3.8           200
# 10                               Spirit     Mumbai     NaN           850
# 11                           Purple Box     Mumbai     3.9           200
# ...

# %%
df.head(10)
# Out:
#                             name       city  rating  cost_for_two  \
# 0         Gabbar's Bar & Kitchen    Kolkata     4.3          1500
# 1    Sardaar Ji De Chole Bhature  Delhi NCR     3.6           100
# 2                    YellowKrust  Delhi NCR     3.8           400
# 3                Hungry Minister  Delhi NCR     3.7           400
# 4                Night Food Xprs  Delhi NCR     3.3           500
# 5          HOP House of Proteins  Delhi NCR     4.8           600
# 6  Daana Paani Family Restaurant    Kolkata     3.4           300
# 7                Swad Restaurant  Delhi NCR     3.8           750
# 8                 Chai Peeni Hai  Delhi NCR     3.7           200
# 9                 Baskin Robbins     Mumbai     3.8           200
#
#                                               cusine online_order  \
# 0            North Indian, Chinese, Mexican, Italian        False
# 1                                       North Indian         True
# ...

# %%
df.tail(10)
# Out:
#                                    name       city  rating  cost_for_two  \
# 10                               Spirit     Mumbai     NaN           850
# 11                           Purple Box     Mumbai     3.9           200
# 12                            Mio Amore    Kolkata     3.4           150
# 13                          Talli Pangs  Delhi NCR     3.7           300
# 14                           Just Baked    Kolkata     3.3           250
# 15                             Monginis     Mumbai     3.4           200
# 16                    The Bohri Kitchen     Mumbai     4.8           600
# 17                       Italy in a Box     Mumbai     NaN           800
# 18                         PizzaExpress     Mumbai     4.3          1900
# 19  Artusi Ristorante in Piazza Horizon  Delhi NCR     4.3          3500
#
#                             cusine online_order table_reservation
# 10  Chinese, North Indian, Mughlai          NaN               NaN
# ...

# %%
df.sample(5)
# Out:
#                              name       city  rating  cost_for_two  \
# 4                 Night Food Xprs  Delhi NCR     3.3           500
# 10                         Spirit     Mumbai     NaN           850
# 3                 Hungry Minister  Delhi NCR     3.7           400
# 6   Daana Paani Family Restaurant    Kolkata     3.4           300
# 7                 Swad Restaurant  Delhi NCR     3.8           750
#
#                                       cusine online_order table_reservation
# 4                      North Indian, Chinese         True             False
# 10            Chinese, North Indian, Mughlai          NaN               NaN
# 3   Continental, Mexican, Fast Food, Chinese         True             False
# 6                      North Indian, Chinese         True             False
# 7             North Indian, Chinese, Mughlai         True             False

# %%
df.shape
# Out:
# (20, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               20 non-null     object
#  1   city               20 non-null     object
#  2   rating             18 non-null     float64
#  3   cost_for_two       20 non-null     int64
#  4   cusine             20 non-null     object
#  5   online_order       18 non-null     object
#  6   table_reservation  18 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#           rating  cost_for_two
# count  18.000000     20.000000
# mean    3.850000    685.000000
# std     0.470607    807.057684
# min     3.300000    100.000000
# 25%     3.450000    200.000000
# 50%     3.750000    400.000000
# 75%     4.200000    762.500000
# max     4.800000   3500.000000

# %%
df.describe(include='object')
# Out:
#                           name       city                 cusine online_order  \
# count                       20         20                     20           18
# unique                      20          3                     18            2
# top     Gabbar's Bar & Kitchen  Delhi NCR  North Indian, Chinese         True
# freq                         1          9                      2           11
#
#        table_reservation
# count                 18
# unique                 2
# top                False
# freq                  15

# %%
df['city']
# Out:
# 0       Kolkata
# 1     Delhi NCR
# 2     Delhi NCR
# 3     Delhi NCR
# 4     Delhi NCR
# 5     Delhi NCR
# 6       Kolkata
# 7     Delhi NCR
# 8     Delhi NCR
# 9        Mumbai
# 10       Mumbai
# 11       Mumbai
# 12      Kolkata
# 13    Delhi NCR
# 14      Kolkata
# 15       Mumbai
# 16       Mumbai
# 17       Mumbai
# 18       Mumbai
# 19    Delhi NCR
# Name: city, dtype: object

# %%
df[["city","rating"]]
# Out:
#          city  rating
# 0     Kolkata     4.3
# 1   Delhi NCR     3.6
# 2   Delhi NCR     3.8
# 3   Delhi NCR     3.7
# 4   Delhi NCR     3.3
# 5   Delhi NCR     4.8
# 6     Kolkata     3.4
# 7   Delhi NCR     3.8
# 8   Delhi NCR     3.7
# 9      Mumbai     3.8
# 10     Mumbai     NaN
# 11     Mumbai     3.9
# 12    Kolkata     3.4
# 13  Delhi NCR     3.7
# 14    Kolkata     3.3
# 15     Mumbai     3.4
# 16     Mumbai     4.8
# 17     Mumbai     NaN
# 18     Mumbai     4.3
# 19  Delhi NCR     4.3

# %%
df["cost_for_two"].mean()
# Out:
# 685.0

# %%
df["cost_for_two"].min()
# Out:
# 100

# %%
df["cost_for_two"].min(),df["cost_for_two"].max()
# Out:
# (100, 3500)

# %%
df["ROI"] = df["rating"]/df["cost_for_two"]

# %%
df
# Out:
#                                    name       city  rating  cost_for_two  \
# 0                Gabbar's Bar & Kitchen    Kolkata     4.3          1500
# 1           Sardaar Ji De Chole Bhature  Delhi NCR     3.6           100
# 2                           YellowKrust  Delhi NCR     3.8           400
# 3                       Hungry Minister  Delhi NCR     3.7           400
# 4                       Night Food Xprs  Delhi NCR     3.3           500
# 5                 HOP House of Proteins  Delhi NCR     4.8           600
# 6         Daana Paani Family Restaurant    Kolkata     3.4           300
# 7                       Swad Restaurant  Delhi NCR     3.8           750
# 8                        Chai Peeni Hai  Delhi NCR     3.7           200
# 9                        Baskin Robbins     Mumbai     3.8           200
# 10                               Spirit     Mumbai     NaN           850
# 11                           Purple Box     Mumbai     3.9           200
# ...

# %%
count=0
for i in df['cost_for_two']:
  if i>1000:
    count+=1
print(count)
# Out:
# 3

# %%
df['Expensive']=df['cost_for_two']>1000
df['Expensive']
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# Name: Expensive, dtype: bool

# %%
df[df["city"]=='Mumbai']
# Out:
#                  name    city  rating  cost_for_two  \
# 9      Baskin Robbins  Mumbai     3.8           200
# 10             Spirit  Mumbai     NaN           850
# 11         Purple Box  Mumbai     3.9           200
# 15           Monginis  Mumbai     3.4           200
# 16  The Bohri Kitchen  Mumbai     4.8           600
# 17     Italy in a Box  Mumbai     NaN           800
# 18       PizzaExpress  Mumbai     4.3          1900
#
#                             cusine online_order table_reservation       ROI  \
# 9   Ice Cream, Desserts, Beverages        False             False  0.019000
# 10  Chinese, North Indian, Mughlai          NaN               NaN       NaN
# 11  Fast Food, Beverages, Desserts         True             False  0.019500
# 15               Bakery, Fast Food         True             False  0.017000
# 16  Mughlai, North Indian, Biryani          NaN               NaN  0.008000
# 17            Italian, Continental         True             False       NaN
# ...

# %%
df[(df["city"]=='Mumbai')&(df['rating']>4)]
# Out:
#                  name    city  rating  cost_for_two  \
# 16  The Bohri Kitchen  Mumbai     4.8           600
# 18       PizzaExpress  Mumbai     4.3          1900
#
#                             cusine online_order table_reservation       ROI  \
# 16  Mughlai, North Indian, Biryani          NaN               NaN  0.008000
# 18                  Italian, Pizza         True              True  0.002263
#
#     Expensive
# 16      False
# 18       True

# %%
df[df['cusine']=='Italian']
# Out:
#                                    name       city  rating  cost_for_two  \
# 19  Artusi Ristorante in Piazza Horizon  Delhi NCR     4.3          3500
#
#      cusine online_order table_reservation       ROI  Expensive
# 19  Italian        False              True  0.001229       True

# %%
df.iloc[2]
# Out:
# name                      YellowKrust
# city                        Delhi NCR
# rating                            3.8
# cost_for_two                      400
# cusine               Bakery, Desserts
# online_order                    False
# table_reservation               False
# ROI                            0.0095
# Expensive                       False
# Name: 2, dtype: object

# %%
df.iloc[1:3]
# Out:
#                           name       city  rating  cost_for_two  \
# 1  Sardaar Ji De Chole Bhature  Delhi NCR     3.6           100
# 2                  YellowKrust  Delhi NCR     3.8           400
#
#              cusine online_order table_reservation     ROI  Expensive
# 1      North Indian         True             False  0.0360      False
# 2  Bakery, Desserts        False             False  0.0095      False
